# %% [markdown]
# <a href="https://colab.research.google.com/github/EdineyBlasques/ListadeExercicios/blob/main/C%C3%B3pia_de_Ediney_Prova_2%C2%BABimentre.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
funcionarios=pd.read_csv("funcionarios.csv")

# %%
funcionarios.head()
# Out:
#               cpf  matricula     sobrenome     nome  \
# 0  931.537.599-93  201309864   Castellanos    Carol
# 1  364.499.792-29  200820853           Law   Esther
# 2  745.251.246-47  201736456        Miller   Thomas
# 3  825.847.582-24  201018824       Escobar    Kevin
# 4  396.646.311-55  201720534        Fisher    Aaron
#
#                                 email           data de ingresso
# 0   carol.castellanos@incolume.com.br   Wed Sep 25 09:02:28 2013
# 1          esther.law@incolume.com.br   Thu Jul 10 12:20:56 2008
# 2       thomas.miller@incolume.com.br   Sat Jan 21 09:45:38 2017
# 3       kevin.escobar@incolume.com.br   Tue Sep 21 23:21:39 2010
# 4        aaron.fisher@incolume.com.br   Sat Apr 29 07:40:15 2017

# %%
funcionarios.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30 entries, 0 to 29
# Data columns (total 6 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   cpf               30 non-null     object
#  1   matricula         30 non-null     int64
#  2   sobrenome         30 non-null     object
#  3   nome              30 non-null     object
#  4   email             30 non-null     object
#  5   data de ingresso  30 non-null     object
# dtypes: int64(1), object(5)
# memory usage: 1.5+ KB

# %%
funcionarios["cpf"]
# Out:
# 0     931.537.599-93
# 1     364.499.792-29
# 2     745.251.246-47
# 3     825.847.582-24
# 4     396.646.311-55
# 5     289.450.336-93
# 6     228.143.194-31
# 7     577.374.444-72
# 8     152.652.064-08
# 9     759.153.822-09
# 10    634.152.741-68
# 11    729.411.520-02
# 12    106.592.087-79
# 13    521.826.556-76
# 14    271.977.018-54
# 15    361.704.644-66
# 16    885.562.374-75
# 17    502.959.008-67
# 18    328.167.580-89
# 19    836.147.889-22
# 20    658.564.254-70
# 21    193.871.879-06
# 22    385.877.307-93
# 23    552.580.255-37
# 24    568.047.931-52
# 25    462.449.026-48
# 26    071.967.112-60
# 27    786.647.740-21
# 28    779.505.069-50
# 29    353.741.071-56
# Name: cpf, dtype: object

# %%
funcionarios["cpf"]=funcionarios["cpf"].apply(lambda x:x.replace(".",""))

# %%
funcionarios["cpf"]=funcionarios["cpf"].apply(lambda x:x.replace("-",""))

# %%
funcionarios["cpf"]
# Out:
# 0     93153759993
# 1     36449979229
# 2     74525124647
# 3     82584758224
# 4     39664631155
# 5     28945033693
# 6     22814319431
# 7     57737444472
# 8     15265206408
# 9     75915382209
# 10    63415274168
# 11    72941152002
# 12    10659208779
# 13    52182655676
# 14    27197701854
# 15    36170464466
# 16    88556237475
# 17    50295900867
# 18    32816758089
# 19    83614788922
# 20    65856425470
# 21    19387187906
# 22    38587730793
# 23    55258025537
# 24    56804793152
# 25    46244902648
# 26    07196711260
# 27    78664774021
# 28    77950506950
# 29    35374107156
# Name: cpf, dtype: object

# %%
funcionarios["completo"]=funcionarios["nome"].map(str)+" "+funcionarios["sobrenome"].map(str)
funcionarios["completo"]
# Out:
# 0      Carol  Castellanos
# 1             Esther  Law
# 2          Thomas  Miller
# 3          Kevin  Escobar
# 4           Aaron  Fisher
# 5         Michael  Mcnair
# 6         Richard  Hecker
# 7        Ronald  Odonnell
# 8         Randall  Downey
# 9           Larry  Tipton
# 10      Donna  Dahlheimer
# 11           Gary  Wilson
# 12            Lena  Scott
# 13       Shirley  Thorell
# 14       Victoria  Sawyer
# 15       Victoria  Llanas
# 16          Judith  Baron
# 17         Wayne  Cherian
# 18          Bertha  White
# 19          Yvonne  Reder
# 20          Rebecca  Adam
# 21        Gerald  Lambert
# 22         Amber  Stewart
# 23         Leon  Sterling
# 24      Jeffrey  Upchurch
# 25        Kate  Jorgensen
# 26            Lois  Joyce
# 27        Lawrence  Clark
# 28        Michael  Crouch
# 29       Russell  Marquis
# Name: completo, dtype: object

# %%
nomes=[]
for x in funcionarios["completo"]:
  nomes.append(x)

# %%
nomes
# Out:
# [' Carol  Castellanos',
#  ' Esther  Law',
#  ' Thomas  Miller',
#  ' Kevin  Escobar',
#  ' Aaron  Fisher',
#  ' Michael  Mcnair',
#  ' Richard  Hecker',
#  ' Ronald  Odonnell',
#  ' Randall  Downey',
#  ' Larry  Tipton',
#  ' Donna  Dahlheimer',
#  ' Gary  Wilson',
#  ' Lena  Scott',
#  ' Shirley  Thorell',
#  ' Victoria  Sawyer',
#  ' Victoria  Llanas',
#  ' Judith  Baron',
#  ' Wayne  Cherian',
#  ' Bertha  White',
#  ' Yvonne  Reder',
#  ' Rebecca  Adam',
#  ' Gerald  Lambert',
#  ' Amber  Stewart',
#  ' Leon  Sterling',
#  ' Jeffrey  Upchurch',
#  ' Kate  Jorgensen',
#  ' Lois  Joyce',
#  ' Lawrence  Clark',
#  ' Michael  Crouch',
#  ' Russell  Marquis']

# %%
def votacao_corrupta(voto):
  candJubis=(voto*24)//100
  candCremil=(voto*35)//100
  candMaique=(voto*40)//100
  if candMaique==candCremil:
    candCremil=candCremil-1
    candMaique=candMaique+1
  elif candMaique==candJubis:
    candJubis=candJubis-1
    candMaique=candMaique+1
  votonulo=voto-candJubis-candCremil-candMaique
  print(f"Jubiscreives: {(candJubis)}")
  print(f"Cremilson: {(candCremil)}")
  print(f"Maique Táison: {(candMaique)}")
  print(f"nulos: {(votonulo)}")
  print('\nO Ganhador da Eleição é: Maique Táison')

# %%
def votacao_correta(cand25,cand38,cand41,nulo):
    print(f"Jubiscreives: {len(cand25)}")
    print(f"Cremilson: {len(cand38)}")
    print(f"Maique Táison: {len(cand41)}")
    print(f"nulos: {len(nulo)}")

# %%
cpfvalidos=[]
for x in funcionarios['cpf']:
  cpfvalidos.append(x)

# %%
#Tentativa2
print('Votação para Presidente da Empresa Tal\n')
votos=[]
cand25=[]
cand38=[]
cand41=[]
nulo=[]
fim=False
iniciocpf=False
while iniciocpf==False:
  cpf=input("digite o cpf: ")
  cpf1=int(cpf)
  fim=False
  for i,num in enumerate(cpfvalidos):    
    if cpf==num:      
      print(nomes[i])
      print('\n')
      cpfvalidos.remove(cpf)
      del nomes[i]
      while fim==False:
        votacao=int(input("Digite o numero do seu canditado: "))
        if votacao==25:
          votos.append(votacao)
          cand25.append(votacao)
          print("A empresa agradeçe a sua colaboração.\n")
          fim=True
                    
        elif votacao==38:
          votos.append(votacao)
          cand38.append(votacao)
          print("A empresa agradeçe a sua colaboração.\n")
          fim=True
                   
        elif votacao==41:
          votos.append(votacao)
          cand41.append(votacao)
          print("A empresa agradeçe a sua colaboração.\n")
          fim=True
          
        elif votacao==555512342022:
          print("\n****** fim da votação ******\n")
          Total_votos=len(votos+nulo)
          print(f'Total de votos {Total_votos}.')
          votacao_corrupta(Total_votos)
          fim=True
          iniciocpf=True
         
        elif votacao==12342022:
          print("\n****** fim da votação ******\n")
          Total_votos=len(votos+nulo)
          print(f'Total de votos {Total_votos}.'),
          votacao_correta(cand25,cand38,cand41,nulo)
          fim=True
          iniciocpf=True
         
        else:
          nulo.append(0)
          print("A empresa agradeçe a sua colaboração.\n")
          fim=True
          
    
  if cpf1==555512342022:
          print("\n****** fim da votação ******\n")
          Total_votos=len(votos+nulo)
          print(f'Total de votos {Total_votos}.')
          votacao_corrupta(Total_votos)
          fim=True
          iniciocpf=True
          
  elif cpf1==12342022:
          print("\n****** fim da votação ******\n")
          Total_votos=len(votos+nulo)
          print(f'Total de votos {Total_votos}.'),
          votacao_correta(cand25,cand38,cand41,nulo)
          fim=True
          iniciocpf=True
# Out:
# Votação para Presidente da Empresa Tal
#
# digite o cpf: 09029179945
# digite o cpf: 35374107156
#  Russell  Marquis
#
#
# Digite o numero do seu canditado: 25
# A empresa agradeçe a sua colaboração.
#
# digite o cpf: 77950506950
#  Michael  Crouch
#
#
# Digite o numero do seu canditado: 25
# A empresa agradeçe a sua colaboração.
#
# digite o cpf: 77950506950
# digite o cpf: 78664774021
#  Lawrence  Clark
#
#
# Digite o numero do seu canditado: 25
# A empresa agradeçe a sua colaboração.
#
# digite o cpf: 000012342022
#
# ****** fim da votação ******
#
# Total de votos 3.
# Jubiscreives: 3
# Cremilson: 0
# Maique Táison: 0
# nulos: 0

# %%
# #Tentativa1 deu certo
# print('Votação para Presidente da Empresa Tal\n')
# votos=[]
# cand25=[]
# cand38=[]
# cand41=[]
# nulo=[]
# fim=False
# iniciocpf=False
# while iniciocpf==False:
#   cpf=input("digite o cpf: ")
#   cpf1=int(cpf)
#   fim=False
#   for i,num in enumerate(cpfvalidos):    
#     if cpf==num:      
#       print(nomes[i])
#       print('\n')
#       while fim==False:
#         votacao=int(input("Digite o numero do seu canditado: "))
#         if votacao==25:
#           votos.append(votacao)
#           cand25.append(votacao)
#           print("A empresa agradeçe a sua colaboração.\n")
#           fim=True
                    
#         elif votacao==38:
#           votos.append(votacao)
#           cand38.append(votacao)
#           print("A empresa agradeçe a sua colaboração.\n")
#           fim=True
                   
#         elif votacao==41:
#           votos.append(votacao)
#           cand41.append(votacao)
#           print("A empresa agradeçe a sua colaboração.\n")
#           fim=True
          
#         elif votacao==555512342022:
#           print("\n****** fim da votação ******\n")
#           Total_votos=len(votos+nulo)
#           print(f'Total de votos {Total_votos}.')
#           votacao_corrupta(Total_votos)
#           fim=True
#           iniciocpf=True
         
#         elif votacao==12342022:
#           print("\n****** fim da votação ******\n")
#           Total_votos=len(votos+nulo)
#           print(f'Total de votos {Total_votos}.'),
#           votacao_correta(cand25,cand38,cand41,nulo)
#           fim=True
#           iniciocpf=True
         
#         else:
#           nulo.append(0)
#           print("A empresa agradeçe a sua colaboração.\n")
#           fim=True
          
    
#   if cpf1==555512342022:
#           print("\n****** fim da votação ******\n")
#           Total_votos=len(votos+nulo)
#           print(f'Total de votos {Total_votos}.')
#           votacao_corrupta(Total_votos)
#           fim=True
#           iniciocpf=True
          
#   elif cpf1==12342022:
#           print("\n****** fim da votação ******\n")
#           Total_votos=len(votos+nulo)
#           print(f'Total de votos {Total_votos}.'),
#           votacao_correta(cand25,cand38,cand41,nulo)
#           fim=True
#           iniciocpf=True
# Out:
# Votação para Presidente da Empresa Tal
#
# digite o cpf: 28945033693
#  Michael  Mcnair
#
#
# Digite o numero do seu canditado: 25
# A empresa agradeçe a sua colaboração.
#
# digite o cpf: 35374107156
#  Russell  Marquis
#
#
# Digite o numero do seu canditado: 25
# A empresa agradeçe a sua colaboração.
#
# digite o cpf: 56804793152
#  Jeffrey  Upchurch
#
#
# Digite o numero do seu canditado: 31
# A empresa agradeçe a sua colaboração.
#
# digite o cpf: 555512342022
#
# ****** fim da votação ******
#
# Total de votos 3.
# Jubiscreives: 0
# Cremilson: 0
# Maique Táison: 2
# nulos: 1
#
# O Ganhador da Eleição é: Maique Táison

# %%
# #Resposta Com um voto
# print('Votação para Presidente da Empresa Tal\n')
# votos=[]
# cand25=[]
# cand38=[]
# cand41=[]
# nulo=[]
# fim=False
# iniciocpf=False
# while iniciocpf==False:
#   cpf=input("digite o cpf: ")
#   for i,num in enumerate(cpfvalidos):
#     if cpf==num:
#       print("\n")
#       print(nomes[i])
#       print("\n")
#   cpf1=int(cpf)
#   fim=False
#   for num in funcionarios["cpf"]:

#     if cpf==num:
#       while fim==False:
#         votacao=int(input("Digite o numero do seu canditado: "))
#         if votacao==25:
#           votos.append(votacao)
#           cand25.append(votacao)
#           print("A empresa agradeçe a sua colaboração.\n")
#           fim=True
          
#         elif votacao==38:
#           votos.append(votacao)
#           cand38.append(votacao)
#           print("A empresa agradeçe a sua colaboração.\n")
#           fim=True
          
#         elif votacao==41:
#           votos.append(votacao)
#           cand41.append(votacao)
#           print("A empresa agradeçe a sua colaboração.\n")
#           fim=True
          
#         elif votacao==555512342022:
#           print("\n****** fim da votação ******\n")
#           Total_votos=len(votos+nulo)
#           print(f'Total de votos {Total_votos}.')
#           votacao_corrupta(Total_votos)
#           fim=True
#           iniciocpf=True
          
#         elif votacao==12342022:
#           print("\n****** fim da votação ******\n")
#           Total_votos=len(votos+nulo)
#           print(f'Total de votos {Total_votos}.'),
#           votacao_correta(cand25,cand38,cand41,nulo)
#           fim=True
#           iniciocpf=True
#         else:
#           nulo.append(0)
#           print("A empresa agradeçe a sua colaboração.\n")
#           fim=True
    
#   if cpf1==555512342022:
#           print("\n****** fim da votação ******\n")
#           Total_votos=len(votos+nulo)
#           print(f'Total de votos {Total_votos}.')
#           votacao_corrupta(Total_votos)
#           fim=True
#           iniciocpf=True
          
#   elif cpf1==12342022:
#           print("\n****** fim da votação ******\n")
#           Total_votos=len(votos+nulo)
#           print(f'Total de votos {Total_votos}.'),
#           votacao_correta(cand25,cand38,cand41,nulo)
#           fim=True
#           iniciocpf=True
# Out:
# Votação para Presidente da Empresa Tal
#
# digite o cpf: 77950506950
# Digite o numero do seu canditado: 25
# A empresa agradeçe a sua colaboração.
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-122-e2ce4b99c222> in <module>
#       9 iniciocpf=False
#      10 while iniciocpf==False:
# ---> 11   cpf=input("digite o cpf: ")
#      12   for i,num in enumerate(cpfvalidos):
#      13     if cpf==num:
#
# /usr/local/lib/python3.8/dist-packages/ipykernel/kernelbase.py in raw_input(self, prompt)
#     858                 "raw_input was called, but this frontend does not support input requests."
#     859             )
# --> 860         return self._input_request(str(prompt),
#     861             self._parent_ident,
#     862             self._parent_header,
#
# /usr/local/lib/python3.8/dist-packages/ipykernel/kernelbase.py in _input_request(self, prompt, ident, parent, password)
#     902             except KeyboardInterrupt:
#     903                 # re-raise KeyboardInterrupt, to truncate traceback
# --> 904                 raise KeyboardInterrupt("Interrupted by user") from None
#     905             except Exception as e:
#     906                 self.log.warning("Invalid Message:", exc_info=True)
#
# KeyboardInterrupt: Interrupted by user

# %%
# #Resposta Com um voto
# print('Votação para Presidente da Empresa Tal\n')
# votos=[]
# cand25=[]
# cand38=[]
# cand41=[]
# nulo=[]
# funcionariolis=[]
# fim=False
# iniciocpf=False

# while iniciocpf==False:
#   cpf=input("digite o cpf: ")
#   cpf1=int(cpf)
#   fim=False
#   for num in enumerate(funcionarios["cpf"]:

#     if cpf==num:
#       while fim==False:
#         votacao=int(input("Digite o numero do seu canditado: "))
#         if votacao==25:
#           votos.append(votacao)
#           cand25.append(votacao)
#           print("A empresa agradeçe a sua colaboração.\n")
#           fim=True
          
#         elif votacao==38:
#           votos.append(votacao)
#           cand38.append(votacao)
#           print("A empresa agradeçe a sua colaboração.\n")
#           fim=True
          
#         elif votacao==41:
#           votos.append(votacao)
#           cand41.append(votacao)
#           print("A empresa agradeçe a sua colaboração.\n")
#           fim=True
          
#         elif votacao==555512342022:
#           print("\n****** fim da votação ******\n")
#           Total_votos=len(votos+nulo)
#           print(f'Total de votos {Total_votos}.')
#           votacao_corrupta(Total_votos)
#           fim=True
#           iniciocpf=True
          
#         elif votacao==12342022:
#           print("\n****** fim da votação ******\n")
#           Total_votos=len(votos+nulo)
#           print(f'Total de votos {Total_votos}.'),
#           votacao_correta(cand25,cand38,cand41,nulo)
#           fim=True
#           iniciocpf=True
#         else:
#           nulo.append(0)
#           print("A empresa agradeçe a sua colaboração.\n")
#           fim=True
    
#   if cpf1==555512342022:
#           print("\n****** fim da votação ******\n")
#           Total_votos=len(votos+nulo)
#           print(f'Total de votos {Total_votos}.')
#           votacao_corrupta(Total_votos)
#           fim=True
#           iniciocpf=True
          
#   elif cpf1==12342022:
#           print("\n****** fim da votação ******\n")
#           Total_votos=len(votos+nulo)
#           print(f'Total de votos {Total_votos}.'),
#           votacao_correta(cand25,cand38,cand41,nulo)
#           fim=True
#           iniciocpf=True
# Out:
# Votação para Presidente da Empresa Tal
#
# digite o cpf: 09029179945
# digite o cpf: 77950506950
# Digite o numero do seu canditado: 25
# A empresa agradeçe a sua colaboração.
#
# digite o cpf: 77950506950
# Digite o numero do seu canditado: 25
# A empresa agradeçe a sua colaboração.
#
# digite o cpf: 555512342022
#
# ****** fim da votação ******
#
# Total de votos 2.
# Jubiscreives: 0
# Cremilson: -1
# Maique Táison: 1
# nulos: 2
#
# O Ganhador da Eleição é: Maique Táison

# %%
# #Resposta
# print('Votação para Presidente da Empresa Tal\n')
# votos=[]
# cand25=[]
# cand38=[]
# cand41=[]
# nulo=[]
# fim=False
# fin1=False
# iniciocpf=False

# cpf=input("digite o cpf: ")
# cpf1=int(cpf)
# for num in funcionarios["cpf"]:
#    if cpf==num:
#      while fim==False:
#        votacao=int(input("Digite o numero do seu canditado: "))
#        if votacao==25:
#          votos.append(votacao)
#          cand25.append(votacao)
#          print("A empresa agradeçe a sua colaboração.\n")
         
#        elif votacao==38:
#          votos.append(votacao)
#          cand38.append(votacao)
#          print("A empresa agradeçe a sua colaboração.\n")
         
#        elif votacao==41:
#          votos.append(votacao)
#          cand41.append(votacao)
#          print("A empresa agradeçe a sua colaboração.\n")
         
#        elif votacao==555512342022:
#          print("\n****** fim da votação ******\n")
#          Total_votos=len(votos+nulo)
#          print(f'Total de votos {Total_votos}.')
#          votacao_corrupta(Total_votos)
#          fim=True
         
#        elif votacao==12342022:
#          print("\n****** fim da votação ******\n")
#          Total_votos=len(votos+nulo)
#          print(f'Total de votos {Total_votos}.'),
#          votacao_correta(cand25,cand38,cand41,nulo)
#          fim=True
#        else:
#          nulo.append(0)
#          print("A empresa agradeçe a sua colaboração.\n")

#    elif cpf1==555512342022:
#          print("\n****** fim da votação ******\n")
#          Total_votos=len(votos+nulo)
#          print(f'Total de votos {Total_votos}.')
#          votacao_corrupta(Total_votos)
#          fim=True
         
#    elif cpf1==12342022:
#          print("\n****** fim da votação ******\n")
#          Total_votos=len(votos+nulo)
#          print(f'Total de votos {Total_votos}.'),
#          votacao_correta(cand25,cand38,cand41,nulo)
#          fim=True
# Out:
# Votação para Presidente da Empresa Tal
#
# digite o cpf: 555512342022
# ei

# %%
# #Resposta
# print('Votação para Presidente da Empresa Tal\n')
# votos=[]
# cand25=[]
# cand38=[]
# cand41=[]
# nulo=[]
# fim=False
# fin1=False
# iniciocpf=False


# cpf=input("digite o cpf: ")
# cpf1=int(cpf)
# for num in funcionarios["cpf"]:
#    if cpf==num:
#      while fim==False:
#        votacao=int(input("Digite o numero do seu canditado: "))
#        if votacao==25:
#          votos.append(votacao)
#          cand25.append(votacao)
#          print("A empresa agradeçe a sua colaboração.\n")
#          fim=True
         
#        elif votacao==38:
#          votos.append(votacao)
#          cand38.append(votacao)
#          print("A empresa agradeçe a sua colaboração.\n")
#          fim=True
         
#        elif votacao==41:
#          votos.append(votacao)
#          cand41.append(votacao)
#          print("A empresa agradeçe a sua colaboração.\n")
#          fim=True
         
#        elif votacao==555512342022:
#          print("\n****** fim da votação ******\n")
#          Total_votos=len(votos+nulo)
#          print(f'Total de votos {Total_votos}.')
#          votacao_corrupta(Total_votos)
#          fim=True
         
#        elif votacao==12342022:
#          print("\n****** fim da votação ******\n")
#          Total_votos=len(votos+nulo)
#          print(f'Total de votos {Total_votos}.'),
#          votacao_correta(cand25,cand38,cand41,nulo)
#          fim=True
#        else:
#          nulo.append(0)
#          print("A empresa agradeçe a sua colaboração.\n")
#          fim=True

#    elif cpf1==555512342022:
#          print("\n****** fim da votação ******\n")
#          Total_votos=len(votos+nulo)
#          print(f'Total de votos {Total_votos}.')
#          votacao_corrupta(Total_votos)
#          fim=True
         
#    elif cpf1==12342022:
#          print("\n****** fim da votação ******\n")
#          Total_votos=len(votos+nulo)
#          print(f'Total de votos {Total_votos}.'),
#          votacao_correta(cand25,cand38,cand41,nulo)
#          fim=True
# Out:
# Votação para Presidente da Empresa Tal
#
# digite o cpf: 93153759993
# Digite o numero do seu canditado: 25
# A empresa agradeçe a sua colaboração.
#
# Digite o numero do seu canditado: 25
# A empresa agradeçe a sua colaboração.
#
# Digite o numero do seu canditado: 555512342022
#
# ****** fim da votação ******
#
# Total de votos 2.
# Jubiscreives: 0
# Cremilson: -1
# Maique Táison: 1
# nulos: 2
#
# O Ganhador da Eleição é: Maique Táison
